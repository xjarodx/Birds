# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
from splinter import Browser
import time 
from pprint import pprint

# %%
bird = {}

# %%
wiki = 'https://en.wikipedia.org/wiki/barn_swallow'
all_tables = {}

# %%
tables = pd.read_html(wiki)
tables[0]
# Out:
#                                                     0              1
# 0                                        Barn swallow            NaN
# 1                                                 NaN            NaN
# 2                                       H. r. rustica            NaN
# 3                                 Conservation status            NaN
# 4                         Least Concern (IUCN 3.1)[1]            NaN
# 5                           Scientific classification            NaN
# 6                                            Kingdom:       Animalia
# 7                                             Phylum:       Chordata
# 8                                              Class:           Aves
# 9                                              Order:  Passeriformes
# 10                                            Family:   Hirundinidae
# 11                                             Genus:        Hirundo
# 12                                           Species:     H. rustica
# ...

# %%
x = len(tables)
x
# Out:
# 14

# %%
for i in range (0, x):
    table = tables[i]
    all_tables[f'tables_{i}']=table

# %%
for t in all_tables:
     pprint(all_tables[t])
# Out:
#                                                     0              1
# 0                                        Barn swallow            NaN
# 1                                                 NaN            NaN
# 2                                       H. r. rustica            NaN
# 3                                 Conservation status            NaN
# 4                         Least Concern (IUCN 3.1)[1]            NaN
# 5                           Scientific classification            NaN
# 6                                            Kingdom:       Animalia
# 7                                             Phylum:       Chordata
# 8                                              Class:           Aves
# 9                                              Order:  Passeriformes
# 10                                            Family:   Hirundinidae
# 11                                             Genus:        Hirundo
# 12                                           Species:     H. rustica
# ...

# %%
scrape_data = tables[0]
scrape_data
# Out:
#                                                     0              1
# 0                                        Barn swallow            NaN
# 1                                                 NaN            NaN
# 2                                       H. r. rustica            NaN
# 3                                 Conservation status            NaN
# 4                         Least Concern (IUCN 3.1)[1]            NaN
# 5                           Scientific classification            NaN
# 6                                            Kingdom:       Animalia
# 7                                             Phylum:       Chordata
# 8                                              Class:           Aves
# 9                                              Order:  Passeriformes
# 10                                            Family:   Hirundinidae
# 11                                             Genus:        Hirundo
# 12                                           Species:     H. rustica
# ...

# %% [markdown]
# BEGIN PULLING IMAGE

# %%
wiki = 'https://en.wikipedia.org/wiki/barn_swallow'

# %%
response = requests.get(wiki)

# %%
soup = bs(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Barn swallow - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
image_tags = soup.findAll('img')

# %%
print(image_tags)
# Out:
# [<img alt="This is a featured article. Click here for more information." data-file-height="438" data-file-width="462" decoding="async" height="19" src="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/30px-Cscr-featured.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/40px-Cscr-featured.svg.png 2x" width="20"/>, <img alt="Landsvale.jpg" data-file-height="1024" data-file-width="1600" decoding="async" height="141" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Landsvale.jpg/220px-Landsvale.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Landsvale.jpg/330px-Landsvale.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/24/Landsvale.jpg/440px-Landsvale.jpg 2x" width="220"/>, <img alt="" data-file-height="64" data-file-width="240" decoding="async" height="59" src="//upload.wikimedia.org/wikipedia/commons/thumb/5
# ...

# %%
print(image_tags[1])
# Out:
# <img alt="Landsvale.jpg" data-file-height="1024" data-file-width="1600" decoding="async" height="141" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Landsvale.jpg/220px-Landsvale.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Landsvale.jpg/330px-Landsvale.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/24/Landsvale.jpg/440px-Landsvale.jpg 2x" width="220"/>

# %%
img_url = image_tags[1].get("src")
img_url
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/2/24/Landsvale.jpg/220px-Landsvale.jpg'

# %%
loc_img = image_tags[4].get("src")
loc_img
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/3/38/Hirundo_rustica.png/220px-Hirundo_rustica.png'
